# %% [markdown]
# **Guarda Tutte le lezioni di NumPy qui**<br>
# ➡️➡️ [NumPy Playlist](https://www.youtube.com/watch?v=z0gMBWlScmw&list=PLqzZ6UmyLu115CH8xn6TLxxn8yDn7upOo)<br>
# **Se hai qualche domanda o vuoi scrivermi**<br> 🙂
# ➡️➡️ [Linkedln](https://www.linkedin.com/in/rafaelc1532/)<br>
# *Corso di numpy creato da Rafael Carpio*

# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
matriz = arr.reshape(2,5)

# %%
arr
# Out:
# array([11,  1,  9,  3,  8,  1, 19, 10, 10, 15])

# %%
matriz
# Out:
# array([[11,  1,  9,  3,  8],
#        [ 1, 19, 10, 10, 15]])

# %% [markdown]
# # **Funzioni NumPy**

# %%
arr.max()
# Out:
# 19

# %%
arr.argmax()
# Out:
# 6

# %%
arr.min()
# Out:
# 1

# %%
arr.argmin()
# Out:
# 1

# %%
matriz.argmax(1)
# Out:
# array([0, 1])

# %%
matriz.argmin(0)
# Out:
# array([1, 0, 0, 0, 0])

# %% [markdown]
# **PTP**

# %%
arr.ptp()
# Out:
# 18

# %%
matriz.ptp(1)
# Out:
# array([10, 18])

# %% [markdown]
# **Sort**

# %%
arr
# Out:
# array([11,  1,  9,  3,  8,  1, 19, 10, 10, 15])

# %%
arr.sort()

# %%
arr
# Out:
# array([ 1,  1,  3,  8,  9, 10, 10, 11, 15, 19])

# %% [markdown]
# **Percentile**

# %%
np.percentile(arr,50)
# Out:
# 9.5

# %% [markdown]
# **Median**

# %%
np.median(arr)
# Out:
# 9.5

# %%
np.median(matriz,1)
# Out:
# array([ 3., 11.])

# %%
matriz
# Out:
# array([[ 1,  1,  3,  8,  9],
#        [10, 10, 11, 15, 19]])

# %% [markdown]
# **Standard Deviation**

# %%
np.std(arr)**2
# Out:
# 30.610000000000003

# %% [markdown]
# **Var**

# %%
np.var(arr)
# Out:
# 30.610000000000003

# %% [markdown]
# **Mean**

# %%
np.mean(arr)
# Out:
# 8.7

# %% [markdown]
# # Concatenate

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
np.concatenate((a,b), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-bfef04cb1817> in <cell line: 1>()
# ----> 1 np.concatenate((a,b), axis=0)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
a.ndim
# Out:
# 2

# %%
b.ndim
# Out:
# 1

# %% [markdown]
# **Expand_dims**

# %%
b = np.expand_dims(b,axis=0)

# %%
b.ndim
# Out:
# 2

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b
# Out:
# array([[5, 6]])

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# **Transpuesta**

# %%
b
# Out:
# array([[5, 6]])

# %%
b.T
# Out:
# array([[5],
#        [6]])
