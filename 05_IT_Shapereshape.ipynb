# %% [markdown]
# ### Importar librerías

# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2))

# %% [markdown]
# ### Shape

# %%
arr.shape #shape me dice cuantas filas y cuantas columnas tengo
# Out:
# (3, 2)

# %%
arr
# Out:
# array([[7, 9],
#        [4, 8],
#        [1, 6]])

# %% [markdown]
# ### Reshape

# %%
arr.reshape(1,6)
# Out:
# array([[7, 9, 4, 8, 1, 6]])

# %%
arr.reshape(2,3)
# Out:
# array([[7, 9, 4],
#        [8, 1, 6]])

# %%
np.reshape(arr,(1,6))
# Out:
# array([[7, 9, 4, 8, 1, 6]])

# %%
arr #Questo è il array originale.
# Out:
# array([[7, 9],
#        [4, 8],
#        [1, 6]])

# %%
np.reshape(arr,(2,3),'C')
# Out:
# array([[7, 9, 4],
#        [8, 1, 6]])

# %%
np.reshape(arr,(2,3),'F')
# Out:
# array([[7, 1, 8],
#        [4, 9, 6]])

# %%
np.reshape(arr,(2,3),'A') #Voglio che tu faccia come è ottimizzato
#il salvataggio dei dati nella mia memoria
# Out:
# array([[7, 9, 4],
#        [8, 1, 6]])
