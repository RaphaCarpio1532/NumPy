# %% [markdown]
# **Guarda Tutte le lezioni di NumPy qui**<br>
# ➡️➡️ [NumPy Playlist](https://www.youtube.com/watch?v=z0gMBWlScmw&list=PLqzZ6UmyLu115CH8xn6TLxxn8yDn7upOo)<br>
# **Se hai qualche domanda o vuoi scrivermi**<br> 🙂
# ➡️➡️ [Linkedln](https://www.linkedin.com/in/rafaelc1532/)<br>
# *Corso di numpy creato da Rafael Carpio*

# %% [markdown]
# 💻***CODE***💻

# %% [markdown]
# ### Importare la libreria di NumPy

# %%
import numpy as np

# %% [markdown]
# # **Lista Vs. Array**

# %%
#Lista
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ***Transformiamo la lista in un Array***

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# ***Che Tipo di Array Abbiamo?***

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Abbiamo davvero bisogno di 64 bit per uno, due, tre e quatro?.**

# %%
# Esempio di conversione da decimale a binario
print(bin(1))
print(bin(2))
print(bin(3))
print(bin(4))
# Out:
# 0b1
# 0b10
# 0b11
# 0b100

# %%
arr2 =np.array([1,2,3,4], dtype='int8')
arr2
# Out:
# array([1, 2, 3, 4], dtype=int8)

# %% [markdown]
# ### Cambiare il tipo del Array

# %% [markdown]
# Possiamo cambiare il tipo di dato a Float per esempio

# %%
arr = np.array([1,2,3,4], dtype='float64')
arr.dtype
# Out:
# dtype('float64')

# %%
arr
# Out:
# array([1., 2., 3., 4.])

# %%
arr = np.array([0,1,2,3,4])
arr.dtype
# Out:
# dtype('int64')

# %%
arr = arr.astype(np.bool_)
arr
# Out:
# array([False,  True,  True,  True,  True])

# %%
arr = np.array([0,1,2,3,4])
arr = arr.astype(np.string_)
arr
# Out:
# array([b'0', b'1', b'2', b'3', b'4'], dtype='|S21')

# %%
arr = np.array(['15','1','2','3','4'])
arr = arr.astype(np.int8)
arr
# Out:
# array([15,  1,  2,  3,  4], dtype=int8)
